# %%
import json
from pathlib import Path
import numpy as np
import pandas as pd

# %%
path = Path("data/")
out_path = str(path / "processed_endomondoHR_proper.npy")
data_npy = np.load(out_path, allow_pickle=True)[0]

# %%
data_npy
# Out:
# array([{'since_begin': [1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.8892184314, 1378478.889218
# ...

# %%
data = pd.DataFrame(data_npy)
data
# Out:
#                                                         0
# 0       {'since_begin': [1378478.8892184314, 1378478.8...
# 1       {'since_begin': [-14.805054276856485, -14.8050...
# 2       {'since_begin': [-14.805054276856485, -14.8050...
# 3       {'since_begin': [-14.805054276856485, -14.8050...
# 4       {'since_begin': [-14.805054276856485, -14.8050...
# ...                                                   ...
# 167778  {'since_begin': [-14.805054276856485, -14.8050...
# 167779  {'since_begin': [-14.805054276856485, -14.8050...
# 167780  {'since_begin': [-14.805054276856485, -14.8050...
# 167781  {'since_begin': [-14.805054276856485, -14.8050...
# 167782  {'since_begin': [-14.805054276856485, -14.8050...
#
# [167783 rows x 1 columns]

# %%
data = pd.DataFrame(data[0].values.tolist())
data
# Out:
#                                               since_begin  \
# 0       [1378478.8892184314, 1378478.8892184314, 13784...
# 1       [-14.805054276856485, -14.805054276856485, -14...
# 2       [-14.805054276856485, -14.805054276856485, -14...
# 3       [-14.805054276856485, -14.805054276856485, -14...
# 4       [-14.805054276856485, -14.805054276856485, -14...
# ...                                                   ...
# 167778  [-14.805054276856485, -14.805054276856485, -14...
# 167779  [-14.805054276856485, -14.805054276856485, -14...
# 167780  [-14.805054276856485, -14.805054276856485, -14...
# 167781  [-14.805054276856485, -14.805054276856485, -14...
# 167782  [-14.805054276856485, -14.805054276856485, -14...
#
#                                                since_last  \
# 0       [2158.84607810351, 2158.84607810351, 2158.8460...
# 1       [-0.011580266728650795, -0.011580266728650795,...
# 2       [-0.011580266728650795, -0.011580266728650795,...
# ...
